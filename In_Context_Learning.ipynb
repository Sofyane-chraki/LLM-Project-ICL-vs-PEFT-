# %%
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    AutoTokenizer,
    TrainingArguments,
    Trainer,
    GenerationConfig
)
from tqdm import tqdm
from trl import SFTTrainer
import torch
import time
import pandas as pd
import numpy as np
from huggingface_hub import interpreter_login

interpreter_login()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\transformers\utils\import_utils.py:1390, in _LazyModule._get_module(self, module_name)
#    1389 try:
# -> 1390     return importlib.import_module("." + module_name, self.__name__)
#    1391 except Exception as e:
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\transformers\training_args.py:70, in <module>
#      69 if is_accelerate_available():
# ---> 70     from accelerate.state import AcceleratorState, PartialState
#      71     from accelerate.utils import DistributedType
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\__init__.py:16, in <module>
#      14 __version__ = "0.28.0"
# ---> 16 from .accelerator import Accelerator
#      17 from .big_modeling import (
#      18     cpu_offload,
#      19     cpu_offload_with_hook,
#    (...)
#      24     load_checkpoint_and_dispatch,
#      25 )
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\accelerator.py:35, in <module>
#      33 import torch.utils.hooks as hooks
# ---> 35 from .checkpointing import load_accelerator_state, load_custom_state, save_accelerator_state, save_custom_state
#      36 from .data_loader import DataLoaderDispatcher, prepare_data_loader, skip_first_batches
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\checkpointing.py:24, in <module>
#      22 from torch.cuda.amp import GradScaler
# ---> 24 from .utils import (
#      25     MODEL_NAME,
#      26     OPTIMIZER_NAME,
#      27     RNG_STATE_NAME,
#      28     SAFE_MODEL_NAME,
#      29     SAFE_WEIGHTS_NAME,
#      30     SAMPLER_NAME,
#      31     SCALER_NAME,
#      32     SCHEDULER_NAME,
#      33     WEIGHTS_NAME,
#      34     get_pretty_name,
#      35     is_torch_xla_available,
#      36     is_xpu_available,
#      37     save,
#      38 )
#      41 if is_torch_xla_available():
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\utils\__init__.py:171, in <module>
#     162     from .deepspeed import (
#     163         DeepSpeedEngineWrapper,
#     164         DeepSpeedOptimizerWrapper,
#    (...)
#     168         HfDeepSpeedConfig,
#     169     )
# --> 171 from .bnb import has_4bit_bnb_layers, load_and_quantize_model
#     172 from .fsdp_utils import load_fsdp_model, load_fsdp_optimizer, save_fsdp_model, save_fsdp_optimizer
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\utils\bnb.py:29, in <module>
#      24 from accelerate.utils.imports import (
#      25     is_4bit_bnb_available,
#      26     is_8bit_bnb_available,
#      27 )
# ---> 29 from ..big_modeling import dispatch_model, init_empty_weights
#      30 from .dataclasses import BnbQuantizationConfig
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\big_modeling.py:24, in <module>
#      22 import torch.nn as nn
# ---> 24 from .hooks import (
#      25     AlignDevicesHook,
#      26     CpuOffload,
#      27     UserCpuOffloadHook,
#      28     add_hook_to_module,
#      29     attach_align_device_hook,
#      30     attach_align_device_hook_on_blocks,
#      31 )
#      32 from .utils import (
#      33     OffloadedWeightsLoader,
#      34     check_device_map,
#    (...)
#      45     retie_parameters,
#      46 )
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\hooks.py:30, in <module>
#      29 from .utils.modeling import get_non_persistent_buffers
# ---> 30 from .utils.other import recursive_getattr
#      33 class ModelHook:
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\utils\other.py:29, in <module>
#      27 from safetensors.torch import save_file as safe_save_file
# ---> 29 from ..commands.config.default import write_basic_config  # noqa: F401
#      30 from ..logging import get_logger
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\commands\config\__init__.py:19, in <module>
#      17 import argparse
# ---> 19 from .config import config_command_parser
#      20 from .config_args import default_config_file, load_config_from_file  # noqa: F401
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\commands\config\config.py:25, in <module>
#      24 from .config_utils import _ask_field, _ask_options, _convert_compute_environment  # noqa: F401
# ---> 25 from .sagemaker import get_sagemaker_input
#      28 description = "Launches a series of prompts to create and save a `default_config.yaml` configuration file for your training system. Should always be ran first on your machine"
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\accelerate\commands\config\sagemaker.py:35, in <module>
#      34 if is_boto3_available():
# ---> 35     import boto3  # noqa: F401
#      38 def _create_iam_role_for_sagemaker(role_name):
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\boto3\__init__.py:17, in <module>
#      16 from boto3.compat import _warn_deprecated_python
# ---> 17 from boto3.session import Session
#      19 __author__ = 'Amazon Web Services'
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\boto3\session.py:17, in <module>
#      15 import os
# ---> 17 import botocore.session
#      18 from botocore.client import Config
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\session.py:26, in <module>
#      24 import warnings
# ---> 26 import botocore.client
#      27 import botocore.configloader
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\client.py:15, in <module>
#      13 import logging
# ---> 15 from botocore import waiter, xform_name
#      16 from botocore.args import ClientArgsCreator
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\waiter.py:18, in <module>
#      16 import jmespath
# ---> 18 from botocore.docs.docstring import WaiterDocstring
#      19 from botocore.utils import get_service_module_name
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\docs\__init__.py:15, in <module>
#      13 import os
# ---> 15 from botocore.docs.service import ServiceDocumenter
#      18 def generate_docs(root_dir, session):
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\docs\service.py:14, in <module>
#      13 from botocore.docs.bcdoc.restdoc import DocumentStructure
# ---> 14 from botocore.docs.client import ClientDocumenter, ClientExceptionsDocumenter
#      15 from botocore.docs.paginator import PaginatorDocumenter
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\docs\client.py:14, in <module>
#      13 from botocore.compat import OrderedDict
# ---> 14 from botocore.docs.example import ResponseExampleDocumenter
#      15 from botocore.docs.method import (
#      16     document_custom_method,
#      17     document_model_driven_method,
#      18     get_instance_public_methods,
#      19 )
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\docs\example.py:13, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      11 # ANY KIND, either express or implied. See the License for the specific
#      12 # language governing permissions and limitations under the License.
# ---> 13 from botocore.docs.shape import ShapeDocumenter
#      14 from botocore.docs.utils import py_default
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\docs\shape.py:19, in <module>
#       1 # Copyright 2015 Amazon.com, Inc. or its affiliates. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License"). You
#    (...)
#      17 # inherited from a Documenter class with the appropriate methods
#      18 # and attributes.
# ---> 19 from botocore.utils import is_json_value_header
#      22 class ShapeDocumenter(object):
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\utils.py:34, in <module>
#      33 import botocore.awsrequest
# ---> 34 import botocore.httpsession
#      35 from botocore.compat import (
#      36     HAS_CRT,
#      37     MD5_AVAILABLE,
#    (...)
#      47     zip_longest,
#      48 )
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\botocore\httpsession.py:16, in <module>
#      15 from urllib3.util.retry import Retry
# ---> 16 from urllib3.util.ssl_ import (
#      17     DEFAULT_CIPHERS,
#      18     OP_NO_COMPRESSION,
#      19     PROTOCOL_TLS,
#      20     OP_NO_SSLv2,
#      21     OP_NO_SSLv3,
#      22     ssl,
#      23 )
#      25 try:
#
# ImportError: cannot import name 'PROTOCOL_TLS' from 'urllib3.util.ssl_' (c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\urllib3\util\ssl_.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
#       1 from datasets import load_dataset
# ----> 2 from transformers import (
#       3     AutoModelForCausalLM,
#       4     AutoTokenizer,
#       5     BitsAndBytesConfig,
#       6     HfArgumentParser,
#       7     AutoTokenizer,
#       8     TrainingArguments,
#       9     Trainer,
#      10     GenerationConfig
#      11 )
#      12 from tqdm import tqdm
#      13 from trl import SFTTrainer
#
# File <frozen importlib._bootstrap>:1055, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\transformers\utils\import_utils.py:1380, in _LazyModule.__getattr__(self, name)
#    1378     value = self._get_module(name)
#    1379 elif name in self._class_to_module.keys():
# -> 1380     module = self._get_module(self._class_to_module[name])
#    1381     value = getattr(module, name)
#    1382 else:
#
# File c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\transformers\utils\import_utils.py:1392, in _LazyModule._get_module(self, module_name)
#    1390     return importlib.import_module("." + module_name, self.__name__)
#    1391 except Exception as e:
# -> 1392     raise RuntimeError(
#    1393         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1394         f" traceback):\n{e}"
#    1395     ) from e
#
# RuntimeError: Failed to import transformers.training_args because of the following error (look up to see its traceback):
# cannot import name 'PROTOCOL_TLS' from 'urllib3.util.ssl_' (c:\Users\sofyane.chraki\Anaconda3\lib\site-packages\urllib3\util\ssl_.py)

# %%
# !pip install -q -U bitsandbytes transformers peft accelerate datasets scipy einops evaluate trl rouge_score

# %%
# !pip install --upgrade urllib3
# Out:
# Requirement already satisfied: urllib3 in c:\users\sofyane.chraki\anaconda3\lib\site-packages (2.2.1)
